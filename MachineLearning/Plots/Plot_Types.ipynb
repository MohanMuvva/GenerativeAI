# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
from google.colab import files
from plotly.graph_objs import Sunburst
import plotly.express as px
uploaded = files.upload()

# Load the dataset
data = pd.read_csv(next(iter(uploaded.keys())))  # Replace with your file path
# Out:
#      <input type="file" id="files-5239799e-8bcd-4865-839a-2719e25e2c06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5239799e-8bcd-4865-839a-2719e25e2c06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Basic EDA
print("Data Information:")
print(data.info())
print("\nData Description:")
print(data.describe())

# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())

'''
# Pairplot to view feature relationships and distributions
sns.pairplot(data, diag_kind='kde')
plt.suptitle('Pairplot of Dataset Features', y=1.02)
plt.show()


# Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Example of a categorical variable count plot (replace 'affair' with actual column)
sns.countplot(data['affairs'])  # Assuming 'affair' is a categorical variable
plt.title('Count Plot of Affair Status')
plt.show()

# Hierarchical Clustering
# Assuming the dataset requires scaling
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data.select_dtypes(include=['float64', 'int64']))  # Scaling numerical features

# Perform hierarchical clustering
linked = linkage(data_scaled, method='ward')

# Plot  for hierarchical class clustering
plt.figure(figsize=(12, 8))
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
'''

fig = px.sunburst(data, path=['rate_marriage','age', 'yrs_married','children', 'religious', 'educ', 'occupation'], values='affairs')
fig.update_layout(title="Sunburst Plot of Affairs Data", margin=dict(t=40, l=0, r=0, b=0))
fig.show()
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6366 entries, 0 to 6365
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6366 non-null   int64
#  1   rate_marriage    6366 non-null   float64
#  2   age              6366 non-null   float64
#  3   yrs_married      6366 non-null   float64
#  4   children         6366 non-null   float64
#  5   religious        6366 non-null   float64
#  6   educ             6366 non-null   float64
#  7   occupation       6366 non-null   float64
#  8   occupation_husb  6366 non-null   float64
#  9   affairs          6366 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 497.5 KB
# None
#
# Data Description:
#         Unnamed: 0  rate_marriage          age  yrs_married     children  \
# count  6366.000000    6366.000000  6366.000000  6366.000000  6366.000000
# ...
